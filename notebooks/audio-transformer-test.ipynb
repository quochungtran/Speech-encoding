# %% [markdown]
# # Dependency
# pytorch
#
# torchaudio
#
# transformers
#
# datasets
#
# librosa

# %%
from transformers import pipeline
from datasets import load_dataset
import librosa
import matplotlib.pyplot as plt
import librosa.display
## load minds dataset, asking for e-banking queries
minds = load_dataset("PolyAI/minds14", name="en-AU", split="train")
# Out:
# Using the latest cached version of the module from /home/hoang/.cache/huggingface/modules/datasets_modules/datasets/PolyAI--minds14/7bdf27fccad4efc6da7c00f739d96bfa0d25a7a85f2244755a73c865f70182bc (last modified on Fri Feb  7 13:47:05 2025) since it couldn't be found locally at PolyAI/minds14, or remotely on the Hugging Face Hub.

# %% [markdown]
# ## Audio classification

# %%
classifier = pipeline(
    "audio-classification",
    model="anton-l/xtreme_s_xlsr_300m_minds14",
)
# Out:
# 401 Client Error. (Request ID: Root=1-67a729da-4a4bb48d1e82123619d12b62;ef6c6e7c-1ac8-4a68-a6a8-423397296133)
#
# Repository Not Found for url: https://huggingface.co/anton-l/xtreme_s_xlsr_300m_minds14/resolve/main/model.safetensors.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# Invalid credentials in Authorization header
# 401 Client Error. (Request ID: Root=1-67a729da-7a9e40455683a0dc7eccaedf;ffe0fbf2-c8c1-4ebd-b4e0-6e8fe9d39f7d)
#
# Repository Not Found for url: https://huggingface.co/anton-l/xtreme_s_xlsr_300m_minds14/resolve/main/model.safetensors.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# Invalid credentials in Authorization header
# ---------------------------------------------------------------------------
# ...

# %%
classifier(minds[0]["audio"])

# %% [markdown]
# ## Speech commands
# single words for commands

# %%
speech_commands = load_dataset(
    "speech_commands", "v0.02", split="validation", streaming=True
)
sample = next(iter(speech_commands))
# Out:
# README.md:   0%|          | 0.00/12.1k [00:00<?, ?B/s]
# speech_commands.py:   0%|          | 0.00/7.31k [00:00<?, ?B/s]
# The repository for speech_commands contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/speech_commands.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N]  y

# %%
classifier = pipeline(
    "audio-classification", model="MIT/ast-finetuned-speech-commands-v2"
)
classifier(sample["audio"].copy())
# Out:
# config.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/342M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'score': 0.9999892711639404, 'label': 'backward'},
#  {'score': 1.750492174323881e-06, 'label': 'happy'},
#  {'score': 6.703033363919531e-07, 'label': 'follow'},
#  {'score': 5.805890168630867e-07, 'label': 'stop'},
#  {'score': 5.614552378574444e-07, 'label': 'up'}]

# %%
from IPython.display import Audio

Audio(sample["audio"]["array"], rate=sample["audio"]["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## More models can be found here:
#
# https://huggingface.co/models
#
# - TTS: kokoro - 82M params https://huggingface.co/hexgrad/Kokoro-82M
#
# - Language detection: https://huggingface.co/datasets/google/fleurs

# %%
from datasets import load_dataset
fleurs = load_dataset("google/fleurs", "vi_vn", split="train", streaming = True)
ls = iter(fleurs)

# %%
sample = next(ls)

# %%
Audio(sample["audio"]["array"], rate=sample["audio"]["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
classifier = pipeline(
    "audio-classification", model="sanchit-gandhi/whisper-medium-fleurs-lang-id"
)
# Out:
# config.json:   0%|          | 0.00/999 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/151M [00:00<?, ?B/s]
# Some weights of WhisperForAudioClassification were not initialized from the model checkpoint at ihanif/whisper-tiny-ps and are newly initialized: ['model.classifier.bias', 'model.classifier.weight', 'model.projector.bias', 'model.projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
classifier(sample_fleur["audio"])
# Out:
# [{'score': 0.517808198928833, 'label': 'LABEL_0'},
#  {'score': 0.4821917712688446, 'label': 'LABEL_1'}]

# %% [markdown]
# ## Zero-shot learning
# Predict unseen samples with customized labels

# %%
dataset = load_dataset("ashraq/esc50", split="train", streaming=True)
sample = next(iter(dataset))
audio_sample = sample["audio"]["array"]
sample_rate = sample["audio"]["sampling_rate"]

# %%
Audio(audio_sample, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#customized labels
candidate_labels = ["Sound of a dog", "Sound of vacuum cleaner"]

# %%
classifier = pipeline(
    task="zero-shot-audio-classification", model="laion/clap-htsat-unfused"
)
classifier(audio_sample, candidate_labels=candidate_labels)
# Out:
# config.json:   0%|          | 0.00/5.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/615M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/614M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'score': 0.9997242093086243, 'label': 'Sound of a dog'},
#  {'score': 0.0002758318732958287, 'label': 'Sound of vacuum cleaner'}]

# %%
#another label list
candidate_labels = ["lion", "cat", "bird", "dog", "lizard", "tree", "speech"]
classifier(audio_sample, candidate_labels=candidate_labels)
# Out:
# [{'score': 0.2801832854747772, 'label': 'cat'},
#  {'score': 0.2471235692501068, 'label': 'lizard'},
#  {'score': 0.2424742579460144, 'label': 'speech'},
#  {'score': 0.18316057324409485, 'label': 'bird'},
#  {'score': 0.028925098478794098, 'label': 'lion'},
#  {'score': 0.013981875032186508, 'label': 'dog'},
#  {'score': 0.004151421133428812, 'label': 'tree'}]

# %%
from datasets import load_dataset

gtzan = load_dataset("marsyas/gtzan", "all")
gtzan
# Out:
# genres.tar.gz:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 999
#     })
# })

# %%
gtzan = gtzan["train"].train_test_split(seed=42, shuffle=True, test_size=0.1)
gtzan
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 100
#     })
# })

# %%
id2label_fn = gtzan["train"].features["genre"].int2str
id2label_fn(gtzan["train"][0]["genre"])
# Out:
# 'pop'

# %%
import gradio as gr


def generate_audio():
    example = gtzan["train"].shuffle()[0]
    audio = example["audio"]
    return (
        audio["sampling_rate"],
        audio["array"],
    ), id2label_fn(example["genre"])


with gr.Blocks() as demo:
    with gr.Column():
        for _ in range(4):
            audio, label = generate_audio()
            output = gr.Audio(audio, label=label)

demo.launch(debug=True)
# Out:
# /home/hoang/anaconda3/envs/dingi/lib/python3.12/site-packages/gradio/processing_utils.py:741: UserWarning: Trying to convert audio automatically from float64 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.

# %%
from transformers import AutoFeatureExtractor

model_id = "ntu-spml/distilhubert"
feature_extractor = AutoFeatureExtractor.from_pretrained(
    model_id, do_normalize=True, return_attention_mask=True
)
feature_extractor
# Out:
# Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0,
#   "return_attention_mask": true,
#   "sampling_rate": 16000
# }

# %%
sampling_rate = feature_extractor.sampling_rate
sampling_rate
# Out:
# 16000

# %%
from datasets import Audio

gtzan = gtzan.cast_column("audio", Audio(sampling_rate=sampling_rate))

# %%
import numpy as np

sample = gtzan["train"][0]["audio"]

print(f"Mean: {np.mean(sample['array']):.3}, Variance: {np.var(sample['array']):.3}")
# Out:
# Mean: 0.000185, Variance: 0.0493

# %%
# rescale samples such that variance close to 1
inputs = feature_extractor(sample["array"], sampling_rate=sample["sampling_rate"])

print(f"inputs keys: {list(inputs.keys())}")

print(
    f"Mean: {np.mean(inputs['input_values']):.3}, Variance: {np.var(inputs['input_values']):.3}"
)
# Out:
# inputs keys: ['input_values', 'attention_mask']
# Mean: -7.45e-09, Variance: 1.0

# %%
inputs['attention_mask'][0].shape
# Out:
# (480003,)

# %%
max_duration = 30.0


def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
        return_attention_mask=True,
    )
    return inputs
gtzan_encoded = gtzan.map(
    preprocess_function,
    remove_columns=["audio", "file"],
    batched=True,
    batch_size=100,
    num_proc=1,
)
gtzan_encoded
# Out:
# ...
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
gtzan_encoded['train'][0].keys()
# Out:
# dict_keys(['label', 'input_values', 'attention_mask'])

# %%
gtzan_encoded = gtzan_encoded.rename_column("genre", "label")

# %%
id2label = {
    str(i): id2label_fn(i) for i in range(len(gtzan_encoded["train"].features["label"].names))
}
label2id = {v: k for k, v in id2label.items()}

id2label["8"]
# Out:
# 'reggae'

# %%
from transformers import AutoModelForAudioClassification

num_labels = len(id2label)

model = AutoModelForAudioClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
)
# Out:
# model.safetensors:   0%|          | 0.00/94.0M [00:00<?, ?B/s]
# Some weights of HubertForSequenceClassification were not initialized from the model checkpoint at ntu-spml/distilhubert and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from huggingface_hub import notebook_login

notebook_login()
